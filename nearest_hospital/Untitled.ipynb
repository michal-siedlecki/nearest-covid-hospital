# %%
import json

jsonfile = 'hospitals_tr.json'

with open(str(jsonfile)) as datafile:
    data = json.load(datafile)

# %%
for k,v in data.items():
    print(v.get('name'))
# Out:
# WOJEWÓDZKI SPECJALISTYCZNY SZPITAL IM. DR WŁ. BIEGAŃSKIEGO
# SZPITAL WOJEWÓDZKI IM. JANA PAWŁA II W BEŁCHATOWIE
# SZPITAL POWIATOWY W RADOMSKU
# TOMASZOWSKIE CENTRUM ZDROWIA SPÓŁKA Z O.O
# WOJEWÓDZKI ZESPÓŁ ZAKŁADÓW OPIEKI ZDROWOTNEJ CENTRUM LECZENIA CHORÓB
# SZPITAL WOJEWÓDZKI IM. PRYMASA KARDYNAŁA STEFANA WYSZYŃSKIEGO W
# WOJEWÓDZKI SZPITAL ZESPOLONY IM. STANISŁAWA RYBICKIEGO W SKIERNIEWICACH
# "KUTNOWSKI SZPITAL SAMORZĄDOWY" SPÓŁKA
# Z OGRANICZONĄ ODPOWIEDZIALNOŚCIĄ
# WOJEWÓDZKA STACJA RATOWNICTWA MEDYCZNEGO W ŁODZI
# ZESPÓŁ TRANSPORTU SANITARNEGO
# WOJEWÓDZKI SZPITAL SPECJALISTYCZNY IM. MARII SKŁODOWSKIEJ - CURIE W ZGIERZU
# DRAVIS SPÓŁKA Z OGRANICZONĄ ODPOWIEDZIALNOŚCIĄ
# STACJA DIALIZ
# AMERICAN HEART OF POLAND SPÓŁKA AKCYJNA
# ZGIERSKIE CENTRUM KARDIOLOGII MED - PRO POLSKO-AMERYKAŃSKICH KLINIK SERCA
# WOJEWÓDZKI SZPITAL ZESPOLONY W KIELCACH
# WOJEWÓDZKI SZPITAL ZESPOLONY W KIELCACH
# POWIATOWY ZAKŁAD OPIEKI ZDROWOTNEJ W STARACHOWICACH
# ...

# %%
len(data['name'])
# Out:
# 161

# %%
import pandas as pd

# %%
df = pd.read_json('hospitals.json')

# %%
df = df.transpose()

# %%
df.to_json('hospitals_tr.json')
