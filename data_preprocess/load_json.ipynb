# %%
import json

# %%
with open('hospitals.json') as datafile:
    data = json.load(datafile)

# %%
for k, v in data.items():
    print('%s : %s' %(k,v.get('nazwa')))
# Out:
# 0 : WIELOSPECJALISTYCZNY SZPITAL MIEJSKI IM. JÓZEFA STRUSIA Z ZAKŁADEM OPIEKUŃCZO - LECZNICZYM. SAMODZIELNY PUBLICZNY ZAKŁAD OPIEKI ZDROWOTNEJ Z SIEDZIBĄ W POZNANIU PRZY UL. SZWAJCARSKIEJ 3.
# 1 : WOJEWÓDZKI SZPITAL ZESPOLONY IM. DR. ROMANA OSTRZYCKIEGO W KONINIE
# 2 : WOJEWÓDZKI SZPITAL ZESPOLONY IM.LUDWIKA PERZYNY W KALISZU
# 3 : SZPITAL POWIATOWY IM. ROMANA DREWSA W CHODZIEŻY
# 4 : SAMODZIELNY PUBLICZNY ZAKŁAD OPIEKI ZDROWOTNEJ W TURKU
# 5 : SAMODZIELNY PUBLICZNY ZAKŁAD OPIEKI ZDROWOTNEJ W KĘPNIE
# 6 : WOJEWÓDZKI SZPITAL ZESPOLONY W LESZNIE
# 7 : WOJEWÓDZKA STACJA POGOTOWIA RATUNKOWEGO SP ZOZ W POZNANIU
# 8 : SZPITAL POWIATOWY W ŚREMIE SP. Z O.O.
# 9 : WIELKOPOLSKIE CENTRUM RATOWNICTWA MEDYCZNEGO SP. Z O.O W KONINIE
# 10 : SZPITAL MIEJSKI ŚW. JANA PAWŁA II W ELBLĄGU
# 11 : SZPITAL  W OSTRÓDZIE SPÓŁKA AKCYJNA
# 12 : WOJEWÓDZKI SPECJALISTYCZNY SZPITAL DZIECIĘCY IM. PROF. DR STANISŁAWA POPOWSKIEGO W OLSZTYNIE
# 13 : WOJEWÓDZKA STACJA POGOTOWIA RATUNKOWEGO
# ...
